# %% [markdown]
# Step 1: Import packages

# %%
import pandas as pd
from google.colab import drive

# %% [markdown]
# Step 2: Connect to google drive

# %%
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# Step 3: Read data

# %%
df = pd.read_csv("/content/gdrive/MyDrive/ECON 441B/FRED_GDP.csv")
df
# Out:
#            DATE        GDP
# 0    1947-01-01    243.164
# 1    1947-04-01    245.968
# 2    1947-07-01    249.585
# 3    1947-10-01    259.745
# 4    1948-01-01    265.742
# ..          ...        ...
# 298  2021-07-01  23550.420
# 299  2021-10-01  24349.121
# 300  2022-01-01  24740.480
# 301  2022-04-01  25248.476
# 302  2022-07-01  25723.941
#
# [303 rows x 2 columns]

# %% [markdown]
# Step 4: Data cleaning and viz

# %%
# SET INDEX
df.set_index("DATE", inplace= True)
# df = df.set_index("DATE")
df
# Out:
#                   GDP
# DATE
# 1947-01-01    243.164
# 1947-04-01    245.968
# 1947-07-01    249.585
# 1947-10-01    259.745
# 1948-01-01    265.742
# ...               ...
# 2021-07-01  23550.420
# 2021-10-01  24349.121
# 2022-01-01  24740.480
# 2022-04-01  25248.476
# 2022-07-01  25723.941
#
# [303 rows x 1 columns]

# %%
df.index = pd.to_datetime(df.index)
df
# Out:
#                   GDP
# DATE
# 1947-01-01    243.164
# 1947-04-01    245.968
# 1947-07-01    249.585
# 1947-10-01    259.745
# 1948-01-01    265.742
# ...               ...
# 2021-07-01  23550.420
# 2021-10-01  24349.121
# 2022-01-01  24740.480
# 2022-04-01  25248.476
# 2022-07-01  25723.941
#
# [303 rows x 1 columns]

# %%
# Visualization
import matplotlib.pyplot as plt
plt.figure(figsize=(10,5))
plt.title("Real GDP")
plt.xlabel("Date")
plt.ylabel("Billions of dollar")
plt.grid()
plt.plot(df.GDP)
plt.show()

# %% [markdown]
# The most recent real GDP is over 25,000 billion dollars (Annualized seasonally adjusted).
